# %%
# !pip install lingpy
# !pip install Bio
# !pip install numpy
# !pip install pandas
# !pip install random
# !pip install multiprocessing
# !pio install re
# !pip install ast
# Out:
# Requirement already satisfied: lingpy in /usr/local/lib/python3.10/dist-packages (2.6.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lingpy) (1.26.4)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from lingpy) (1.4.4)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.10/dist-packages (from lingpy) (3.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lingpy) (4.66.5)
# Requirement already satisfied: csvw>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from lingpy) (3.3.0)
# Requirement already satisfied: clldutils>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from lingpy) (3.22.2)
# Requirement already satisfied: pycldf>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from lingpy) (1.38.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from lingpy) (4.9.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from clldutils>=2.8.0->lingpy) (2.8.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from clldutils>=2.8.0->lingpy) (0.9.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from clldutils>=2.8.0->lingpy) (6.8.2)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.10/dist-packages (from clldutils>=2.8.0->lingpy) (24.2.0)
# Requirement already satisfied: bibtexparser>=2.0.0b4 in /usr/local/lib/python3.10/dist-packages (from clldutils>=2.8.0->lingpy) (2.0.0b7)
# Requirement already satisfied: pylatexenc in /usr/local/lib/python3.10/dist-packages (from clldutils>=2.8.0->lingpy) (2.10)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from clldutils>=2.8.0->lingpy) (3.6)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.10/dist-packages (from clldutils>=2.8.0->lingpy) (2.1.5)
# Requirement already satisfied: babel in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->lingpy) (2.15.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->lingpy) (0.4.6)
# Requirement already satisfied: isodate in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->lingpy) (0.6.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->lingpy) (4.23.0)
# Requirement already satisfied: language-tags in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->lingpy) (1.2.0)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->lingpy) (7.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->lingpy) (2.32.3)
# Requirement already satisfied: rfc3986<2 in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->lingpy) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->lingpy) (4.1.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pycldf>=1.7.0->lingpy) (6.0.2)
# Requirement already satisfied: commonnexus>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pycldf>=1.7.0->lingpy) (1.9.2)
# Requirement already satisfied: jmespath in /usr/local/lib/python3.10/dist-packages (from pycldf>=1.7.0->lingpy) (1.0.1)
# Requirement already satisfied: newick in /usr/local/lib/python3.10/dist-packages (from pycldf>=1.7.0->lingpy) (1.9.0)
# Requirement already satisfied: pybtex in /usr/local/lib/python3.10/dist-packages (from pycldf>=1.7.0->lingpy) (0.24.0)
# Requirement already satisfied: python-frontmatter in /usr/local/lib/python3.10/dist-packages (from pycldf>=1.7.0->lingpy) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycldf>=1.7.0->lingpy) (71.0.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from pycldf>=1.7.0->lingpy) (2.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate->csvw>=1.5.6->lingpy) (1.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->csvw>=1.5.6->lingpy) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->csvw>=1.5.6->lingpy) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->csvw>=1.5.6->lingpy) (0.20.0)
# Requirement already satisfied: latexcodec>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from pybtex->pycldf>=1.7.0->lingpy) (3.0.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib->csvw>=1.5.6->lingpy) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->csvw>=1.5.6->lingpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->csvw>=1.5.6->lingpy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->csvw>=1.5.6->lingpy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->csvw>=1.5.6->lingpy) (2024.7.4)
# Requirement already satisfied: Bio in /usr/local/lib/python3.10/dist-packages (1.7.1)
# Requirement already satisfied: biopython>=1.80 in /usr/local/lib/python3.10/dist-packages (from Bio) (1.84)
# Requirement already satisfied: gprofiler-official in /usr/local/lib/python3.10/dist-packages (from Bio) (1.0.0)
# Requirement already satisfied: mygene in /usr/local/lib/python3.10/dist-packages (from Bio) (3.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from Bio) (2.1.4)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from Bio) (1.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from Bio) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from Bio) (4.66.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython>=1.80->Bio) (1.26.4)
# Requirement already satisfied: biothings-client>=0.2.6 in /usr/local/lib/python3.10/dist-packages (from mygene->Bio) (0.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->Bio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->Bio) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->Bio) (2024.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch->Bio) (4.2.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch->Bio) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->Bio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->Bio) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->Bio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->Bio) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->Bio) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random
# Collecting multiprocessing
#   Using cached multiprocessing-2.6.2.1.tar.gz (108 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# /bin/bash: line 1: pio: command not found
# Collecting ast
#   Using cached AST-0.0.2.tar.gz (19 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import lingpy
import pandas as pd
import re
from lingpy import *
from Bio import pairwise2
import numpy as np
import ast

def cleanASJP(word):
    """
    Adapted and shortened from Jaeger's cleaning in alignment.py.
    """
    word = re.sub(r"[,\%\"~]", "", word)
    word = re.sub(r"(.)(.)(.)\$", r"\2", word)
    return word.replace('~', '')
#
#
# data = pd.read_csv('albanoRomance.wordpairs.csv')
# data = data.drop(columns=['PMI'])
# data['word1'] = data['word1'].apply(cleanASJP)
# data['word2'] = data['word2'].apply(cleanASJP)
#
# print(data.head())
#
# pmi dict
pmi_df = pd.read_csv('pmi-albanoRomance.csv', index_col=0)
pmi_dict = {}
for i in range(pmi_df.shape[0]):
    for j in range(pmi_df.shape[1]):
        pmi_dict[(pmi_df.columns[j], pmi_df.index[i])] = pmi_df.iloc[i, j]
#
#
#
# def align_word_pairs(df):
#     alignments = []
#
#     for index, row in df.iterrows():
#         seqA = row['word1']
#         seqB = row['word2']
#         try:
#             nw_aln = align.pairwise.nw_align(seqA, seqB, scorer=pmi_dict)
#             sw_aln = align.pairwise.sw_align(seqA, seqB, scorer=pmi_dict)
#             pw_aln = align.pairwise.pw_align(seqA, seqB, mode="dialign")
#         except:
#             continue
#
#         alignments.append({
#             'concept1': row['concept1'],
#             'language1': row['language1'],
#             'word1': row['word1'],
#             'ID1': row['ID1'],
#             'concept2': row['concept2'],
#             'language2': row['language2'],
#             'word2': row['word2'],
#             'ID2': row['ID2'],
#             'nw_alignment': nw_aln,
#             'sw_alignment': sw_aln,
#             'pw_alignment': pw_aln
#         })
#
#     return pd.DataFrame(alignments)
#
#
# alignments_df = align_word_pairs(data)
# alignments_df.to_csv('aligned_lingpy.csv', index=False)


# turchin only returns 0 or 1, not useful

def convert_NW_PW(alignment, keep_score=False):
    """
    Cleaning up for NW alignment.
    """
    if isinstance(alignment, str):
        try:
            parsed_input = ast.literal_eval(alignment)
        except (ValueError, SyntaxError) as e:
            raise ValueError("Wrong alignment format.") from e
    elif isinstance(alignment, tuple):
        parsed_input = alignment
    else:
        raise ValueError("Unsupported alignment format.")

    lists1, lists2, score = parsed_input
    seqA = ''.join(lists1)
    seqB = ''.join(lists2)

    if keep_score:
        return seqA, seqB, score

    return seqA, seqB


# print(convert_NW_PW("(['p', 'o', 'L', '-', '-', '-'], ['-', '-', '-', 'b', 'i', 'e'], -6)", keep_score=True))
# print(convert_NW_PW("(['p', 'o', 'L', '-'], ['-', '-', 'Z', 'u'], -1.44181953287)"))
#
# print("This is PW: \n")
# print(convert_NW_PW("(['p', 'o', 'L', '-', '-', '-'], ['-', '-', '-', 'b', 'i', 'e'], 0.0)"))
# print(convert_NW_PW("(['f', 'e', 'j', '3', '-', '-', '-'], ['-', '-', '-', '-', 'Z', 'u', 'L'], 0.0)"))


def convert_SW(alignment, keep_score=False):
    GAP_SYMBOL = '-'
    if isinstance(alignment, str):
        try:
            parsed_input = ast.literal_eval(alignment)
        except (ValueError, SyntaxError) as e:
            raise ValueError("Wrong alignment format.") from e
    elif isinstance(alignment, tuple):
        parsed_input = alignment
    else:
        raise ValueError("Unsupported alignment format.")

    lists1, lists2, score = parsed_input
    max_cols = max(len(lists1), len(lists2))
    output_lists1 = []
    output_lists2 = []

    for i in range(max_cols):
        seqA = lists1[i] if i < len(lists1) else []
        seqB = lists2[i] if i < len(lists2) else []
        lenA = len(seqA)
        lenB = len(seqB)
        max_len = max(lenA, lenB)
        padded_seqA = ''.join(seqA) + GAP_SYMBOL * (max_len - lenA)
        padded_seqB = ''.join(seqB) + GAP_SYMBOL * (max_len - lenB)
        output_lists1.append(padded_seqA)
        output_lists2.append(padded_seqB)
    final_seqA = ''.join(output_lists1)
    final_seqB = ''.join(output_lists2)

    if keep_score:
        return final_seqA, final_seqB, score

    return final_seqA, final_seqB

# %%
import random as pyrandom

pyrandom.seed(12345)
import numpy as np
from numpy import *
import random
from random import *
import pandas as pd
from Bio import pairwise2
from multiprocessing import Process, Manager
from lingpy import *

import random as pyrandom
pyrandom.seed(12345)
from numpy import *
import numpy as np
random.seed(12345)
import pandas as pd
import re
from Bio import pairwise2
from multiprocessing import Process,Manager


ncores = 50



# Function: nexCharOutput
# Description:
## This function takes a character array, a list of rownames
## and the name of the output nexus file as input
## and writes the character matrix into a nexus file.
## Missing entries are assumed to be coded as "-1"

def nexCharOutput(chMtx, names, outfile, datatype='STANDARD'):
    f = open(outfile, 'w')
    f.write('#NEXUS\n\n')
    f.write('BEGIN DATA;\n')
    f.write('DIMENSIONS ntax=' + str(len(chMtx)) + ' NCHAR=' + str(len(chMtx.T)) + ';\n')
    f.write('FORMAT DATATYPE=' + datatype + ' GAP=? MISSING=- interleave=yes;\n')
    f.write('MATRIX\n\n')
    txLgth = max(map(len, names))
    for i in range(len(chMtx)):
        f.write(names[i].ljust(txLgth + 2))
        for ch in chMtx[i]:
            if ch == -1:
                ch = '-'
            else:
                ch = str(ch)
            f.write(ch)
        f.write('\n')
    f.write('\n;\n\nEND;\n')
    f.close()


data = pd.read_csv('dataset.tab',
                   index_col=0, na_filter=False, sep='\t')
data = data[data.wls_gen.isin(['ROMANCE', 'ALBANIAN'])]
data = data[data.index != 'LATIN']
concepts100 = array(data.columns[9:])
nEntries = data[concepts100].apply(lambda x: sum(x != '')).sort_values()
concepts = nEntries.index[-40:]
data = data[concepts]
taxa = array(data.index)

dataWL = pd.DataFrame([(c,l,cleanASJP(w))
                       for c in concepts
                       for l in taxa
                       for w in data[c][l].split(',')
                       if data[c][l]!=''],
                      columns = ['concept','language','word'])

dataWL = dataWL.drop_duplicates(['concept','language'])

training = pd.DataFrame()
for c in concepts:
    cData = dataWL[dataWL.concept==c]
    cTraining = pd.DataFrame([cData.loc[[i,j]].word.values
                              for i in cData.index
                              for j in cData.index
                              if i<j])
    training = pd.concat([training, cTraining], ignore_index=True)

sounds = unique(concatenate(list(map(list,dataWL.word.values))))


def recalculate_pmi(alignment, gp1, gp2):
    """Recalculate the PMI score based on gap penalties."""
    print(alignment)
    score = alignment[2]
    gap_count = 0
    seqA, seqB = alignment[0], alignment[1]
    for i in range(len(seqA)):
        if seqA[i] == '-' or seqB[i] == '-':
            gap_count += 1
            if gap_count == 1:
                score -= 1
                score += gp1
            else:
                score -= 1
                score += gp2
    return score


def sw_align_lingpy(w, scorer=False, gp1=None, gp2=None, keep_scores=False):
    x, y = w
    sw_aln = lingpy.align.pairwise.sw_align(x, y, scorer=scorer)
    sw_aln = convert_SW(sw_aln, keep_score=keep_scores)
    if gp1 and gp2:
        sw_aln = (sw_aln[0], sw_aln[1], recalculate_pmi(sw_aln, gp1, gp2))
    return sw_aln


def nw_align_lingpy(w, scorer=False, gp1=None, gp2=None, keep_scores=False):
    x, y = w
    nw_aln = lingpy.align.pairwise.nw_align(x, y, scorer=scorer)
    nw_aln = convert_NW_PW(nw_aln, keep_score=keep_scores)
    if gp1 and gp2:
        nw_aln = (nw_aln[0], nw_aln[1], recalculate_pmi(nw_aln, gp1, gp2))
    return nw_aln


def pw_align_lingpy(w, scorer=False, gp1=None, gp2=None, keep_scores=False):
    x, y = w
    pw_aln = lingpy.align.pairwise.pw_align(x, y, mode="dialign")
    pw_aln = convert_NW_PW(pw_aln, keep_score=keep_scores)
    if gp1 and gp2:
        sw_aln = (pw_aln[0], pw_aln[1], recalculate_pmi(pw_aln, gp1, gp2))
    return pw_aln



manager = Manager()
return_dict = manager.dict()
packages = array_split(training.values,ncores)


def doWork(i,pck):
    results = []
    for p in pck:
        alignment = nw_align_lingpy(p)
        if alignment:
            results.append(alignment)
    print(f'Package {i}: Number of successful alignments - {len(results)}') # Print number of successful alignments
    if results:
        return_dict[i] = vstack(results)
        print(f'Package {i}: Results added to return_dict') # Confirm results added to dictionary
    else:
        print(f"Warning: No successful alignments for package {i}")


jobs = []
for i,pck in enumerate(packages):
    p = Process(target=doWork,args=(i,pck))
    p.start()
    jobs.append(p)
for p in jobs:
    p.join()
if return_dict:
  alg0 = vstack(return_dict.values())
else:
  print("Error: the dict is empty")

# count alignment frequencies
sFreqs = pd.crosstab(alg0[:,0],alg0[:,1])
sFreqs = sFreqs.reindex(sounds,fill_value=0).T
sFreqs = sFreqs.reindex(sounds,fill_value=0).T
# symmetrize
sFreqs = sFreqs.copy()+sFreqs.copy().T
# add-1 smoothing
sFreqs += 1
sProbs = sFreqs/sFreqs.sum().sum()

# extract relative sound frequencies
soundOccurrences = concatenate([list(w) for w in dataWL.word.values])
soundProbabilities = pd.value_counts(soundOccurrences,normalize=True)[sounds]
pmi0 = (np.log(sProbs).copy()-np.log(soundProbabilities.to_numpy().reshape(-1, 1))).T-np.log(soundProbabilities.to_numpy().reshape(-1, 1))
print(type(sProbs))
print(sProbs.shape)
print(type(soundProbabilities))
print(soundProbabilities.shape)
print(type(pmi0))
print(pmi0.shape)


def sscore(a, b, pmiDict, gp1, gp2):
    """a,b: ASJP strings
    pmiDict: logodds dictionary
    gp1,gp2: gap penalties
    return PMI score of a/b
    """
    out = pairwise2.align.globalds(a, b, pmiDict, gp1, gp2)
    if len(out) == 0: return nan
    return out[0][2]


def scoreNW(x, y, pmiDict, gp1, gp2):
    """x,y: sequences of ASJP strings, separated by '-'
    pmiDict: logodds dictionary
    gp1,g2: gap penalties
    returns maximal PMI score for the Cartesian product of x and y"""
    if '0' in [x, y]: return nan
    x1 = x.split('-')
    y1 = y.split('-')
    return max([sscore(xx, yy, pmiDict, gp1, gp2) for xx in x1 for yy in y1])


pmi0Dict = {(s1, s2): pmi0[s1][s2]
            for s1 in sounds for s2 in sounds}

def nw(x, y, pmiDict, gp1, gp2):
    """wrapper for Bio.pairwise2.align.globalds"""
    return pairwise2.align.globalds(x, y, pmiDict, gp1, gp2)


# def nwalign(w, pmiDict, gp1, gp2, th=-Inf):
# 	"""w: pair of ASJP strings
# 	pmiDict: dictionary of logodds (=PMI scores)
# 	gp1,gp2: gap penalties (non-positive)
# 	th: threshold; all pairs with a PMI-score <th will be ignored
# 	returns: array of pairwise alignment, with gaps removed"""
# 	x, y = w
# 	a = nw(x, y, pmiDict, gp1, gp2)
# 	if len(a) == 0: return zeros((0, 2))
# 	algn = []
# 	if a[0][2] < th:
# 		return zeros((0, 2))
# 	for aa in a:
# 		l = len(aa[0])
# 		aaa = [[aa[0][i], aa[1][i]] for i in range(l)]
# 		algn += [x for x in aaa if not '-' in x]
# 	return array(algn)

def align_no_gaps(w, pmiDict, gp1, gp2, th=-Inf, mode=None):
    """w: pair of ASJP strings
    pmiDict: dictionary of logodds (=PMI scores)
    gp1,gp2: gap penalties (non-positive)
    th: threshold; all pairs with a PMI-score <th will be ignored
    returns: array of pairwise alignment, with gaps removed"""
    if mode == 'nw':
        a = nw_align_lingpy(w, scorer=pmiDict, keep_scores=True)
    elif mode == 'sw':
        a = sw_align_lingpy(w, scorer=pmiDict, keep_scores=True)
    elif mode == 'pw':
        a = pw_align_lingpy(w, keep_scores=True)
    if len(a) == 0: return zeros((0, 2))
    algn = []
    if a[2] < th if not isnan(a[2]) else False:
        return zeros((0, 2))
    for aa in a:
        l = len(aa[0])
        aaa = [[aa[0][i], aa[1][i]] for i in range(l)]
        algn += [x for x in aaa if not '-' in x]
    return array(algn)
    # if a[0][2] < th:
    #     return zeros((0, 2))
    # for aa in a:
    #     l = len(aa[0])
    #     aaa = [[aa[0][i], aa[1][i]] for i in range(l)]
    #     algn += [x for x in aaa if not '-' in x]
    # return array(algn)


def alignStar(crp, pmiDict, gp1, gp2, th, align_func):
    packages = array_split(crp, ncores)
    manager = Manager()
    return_dict = manager.dict()

    def doWork(i, pck):
        return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
                                 for w in pck])

    jobs = []
    for i, pck in enumerate(packages):
        p = Process(target=doWork, args=(i, pck))
        p.start()
        jobs.append(p)
    for p in jobs:
        p.join()
    return vstack(return_dict.values())


def nwalignStar(crp, pmiDict, gp1, gp2, th):
    return alignStar(crp, pmiDict, gp1, gp2, th, 'nw')


def swalignStar(crp, pmiDict, gp1, gp2, th):
    return alignStar(crp, pmiDict, gp1, gp2, th, 'sw')


def pwalignStar(crp, pmiDict, gp1, gp2, th):
    return alignStar(crp, pmiDict, gp1, gp2, th, 'pw')


gp1 = -2.49302792222
gp2 = -1.70573165621
th = 4.4451

pmiDict = pmi0Dict.copy()
for i in range(10):
    nw_alg = nwalignStar(training.values, pmiDict, gp1, gp2, th)
    sw_alg = swalignStar(training.values, pmiDict, gp1, gp2, th)
    pw_alg = pwalignStar(training.values, pmiDict, gp1, gp2, th)
    for alg, filename in zip([nw_alg, sw_alg, pw_alg], ['nw', 'sw', 'pw']):
        sFreqs = pd.crosstab(alg[:, 0], alg[:, 1])
        sFreqs = sFreqs.reindex(sounds, fill_value=0).T
        sFreqs = sFreqs.reindex(sounds, fill_value=0).T
        sFreqs = sFreqs.copy() + sFreqs.copy().T
        sFreqs += 1
        sProbs = sFreqs / sFreqs.sum().sum()
        pmi = (log(sProbs).copy() - log(soundProbabilities)).T - log(soundProbabilities)
        pmiDict = {(s1, s2): pmi[s1][s2]
                   for s1 in sounds for s2 in sounds}
        pmi.to_csv(f'pmi-albanoRomance-{filename}.csv')

dataWL.to_csv('albanoRomanceASJP_new.csv', index=False)

sc = pd.DataFrame(index=taxa)
for c in concepts:
    cData = dataWL[dataWL.concept == c]
    cTaxa = cData.language.unique()
    cWords = pd.Series([''.join(cData[cData.language == l].word.values)
                        for l in cTaxa],
                       index=cTaxa)
    cMtx = pd.DataFrame([[int(s in cWords[l]) for s in sounds]
                         for l in cTaxa],
                        index=cTaxa)
    cMtx = cMtx.reindex(taxa, fill_value='-')
    sc = pd.concat([sc, cMtx], axis=1)

nexCharOutput(sc.values, sc.index, 'albanoRomanceSC_new.nex', 'restriction')
# Out:
# Package 2: Number of successful alignments - 1040
# Package 3: Number of successful alignments - 1040
# Package 2: Results added to return_dictPackage 1: Number of successful alignments - 1040
# Package 3: Results added to return_dictPackage 1: Results added to return_dict
#
# Package 6: Number of successful alignments - 1040
# Package 0: Number of successful alignments - 1040Package 4: Number of successful alignments - 1040
#
#
# Package 6: Results added to return_dictPackage 8: Number of successful alignments - 1040Package 7: Number of successful alignments - 1040Package 5: Number of successful alignments - 1040Package 4: Results added to return_dictPackage 0: Results added to return_dict
#
#
#
#
#
# Package 7: Results added to return_dictPackage 8: Results added to return_dict
# Package 5: Results added to return_dictPackage 9: Number of successful alignments - 1040
#
#
# Package 9: Results added to return_dictPackage 10: Number of successful alignments - 1040
#
# Package 13: Number of successful alignments - 1039Package 10: Results added to return_dictPackage 12: Number of successful alignments - 1039
# Package 11: Number of successful alignments - 1039
#
# Package 13: Results added to return_dictPackage 12: Results added to return_dict
#
#
# Package 16: Number of successful alignments - 1039Package 11: Results added to return_dictPackage 14: Number of successful alignments - 1039
#
#
# Package 15: Number of successful alignments - 1039
# Package 14: Results added to return_dictPackage 16: Results added to return_dict
#
# Package 15: Results added to return_dict
# Package 18: Number of successful alignments - 1039
# Package 21: Number of successful alignments - 1039Package 18: Results added to return_dictPackage 17: Number of successful alignments - 1039Package 19: Number of successful alignments - 1039
#
#
# Package 22: Number of successful alignments - 1039Package 19: Results added to return_dictPackage 21: Results added to return_dict
# Package 20: Number of successful alignments - 1039
#
#
#
# Package 17: Results added to return_dict
# Package 20: Results added to return_dictPackage 25: Number of successful alignments - 1039Package 22: Results added to return_dict
#
#
# Package 24: Number of successful alignments - 1039Package 25: Results added to return_dictPackage 23: Number of successful alignments - 1039Package 26: Number of successful alignments - 1039
#
#
#
# Package 24: Results added to return_dictPackage 30: Number of successful alignments - 1039Package 26: Results added to return_dict
# Package 23: Results added to return_dictPackage 29: Number of successful alignments - 1039
# Package 28: Number of successful alignments - 1039
#
#
#
# Package 28: Results added to return_dictPackage 30: Results added to return_dict
#
# Package 29: Results added to return_dictPackage 27: Number of successful alignments - 1039
#
# Package 31: Number of successful alignments - 1039Package 27: Results added to return_dict
# Package 32: Number of successful alignments - 1039
# Package 31: Results added to return_dict
# Package 32: Results added to return_dict
# Package 34: Number of successful alignments - 1039
#
# Package 33: Number of successful alignments - 1039Package 35: Number of successful alignments - 1039Package 36: Number of successful alignments - 1039Package 38: Number of successful alignments - 1039Package 34: Results added to return_dict
#
#
#
#
# Package 33: Results added to return_dictPackage 36: Results added to return_dictPackage 35: Results added to return_dict
#
#
# Package 37: Number of successful alignments - 1039Package 38: Results added to return_dict
# Package 39: Number of successful alignments - 1039Package 40: Number of successful alignments - 1039Package 41: Number of successful alignments - 1039
# Package 37: Results added to return_dict
#
#
#
# Package 41: Results added to return_dictPackage 39: Results added to return_dict
#
# Package 40: Results added to return_dictPackage 43: Number of successful alignments - 1039
#
# Package 46: Number of successful alignments - 1039
# Package 43: Results added to return_dictPackage 44: Number of successful alignments - 1039
#
# Package 46: Results added to return_dictPackage 44: Results added to return_dict
#
# Package 42: Number of successful alignments - 1039
# Package 42: Results added to return_dict
# Package 49: Number of successful alignments - 1039
# Package 47: Number of successful alignments - 1039
# Package 48: Number of successful alignments - 1039Package 49: Results added to return_dictPackage 45: Number of successful alignments - 1039
#
# Package 47: Results added to return_dict
#
# Package 45: Results added to return_dictPackage 48: Results added to return_dict
#
# <class 'pandas.core.frame.DataFrame'>
# (38, 38)
# <class 'pandas.core.series.Series'>
# (38,)
# <class 'pandas.core.frame.DataFrame'>
# (38, 38)
# Streaming output truncated to the last 5000 lines.
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
# Process Process-848:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-849:
# IndexError: invalid index to scalar variable.
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
# Process Process-870:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-869:
# Process Process-871:
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-872:
# Traceback (most recent call last):
# Traceback (most recent call last):
# IndexError: invalid index to scalar variable.
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-875:
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
# Traceback (most recent call last):
# IndexError: invalid index to scalar variable.
# IndexError: invalid index to scalar variable.
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
# Process Process-880:
# Process Process-879:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-876:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process Process-882:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-881:
# Traceback (most recent call last):
# Process Process-883:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
# Process Process-887:
# Traceback (most recent call last):
# Process Process-889:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-890:
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
# Process Process-886:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
# IndexError: invalid index to scalar variable.
# IndexError: invalid index to scalar variable.
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
# Process Process-895:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-896:
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# IndexError: invalid index to scalar variable.
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-899:
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# IndexError: invalid index to scalar variable.
# Process Process-903:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-906:
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-900:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# IndexError: invalid index to scalar variable.
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-909:
# IndexError: invalid index to scalar variable.
# Process Process-910:
# Traceback (most recent call last):
# Process Process-911:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process Process-912:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process Process-914:
# Process Process-908:
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-915:
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
# IndexError: invalid index to scalar variable.
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# IndexError: invalid index to scalar variable.
# IndexError: invalid index to scalar variable.
# Process Process-913:
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# IndexError: invalid index to scalar variable.
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
# Process Process-918:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
# Process Process-916:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# IndexError: invalid index to scalar variable.
# Process Process-921:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process Process-920:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process Process-925:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-924:
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
# Process Process-927:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-929:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
# Process Process-922:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-932:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-930:
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-934:
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-931:
# Traceback (most recent call last):
# Process Process-937:
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-936:
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-940:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
# Process Process-942:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-943:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-938:
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-941:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-946:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-947:
# Process Process-945:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
# Process Process-949:
# Traceback (most recent call last):
# Process Process-950:
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process Process-951:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-954:
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-953:
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'float' object is not subscriptable
# Process Process-952:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
# Process Process-957:
# Traceback (most recent call last):
# Process Process-956:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-960:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
# ...
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-1558:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process Process-1557:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-1559:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'float' object is not subscriptable
# Process Process-1561:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
# Process Process-1562:
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process Process-1563:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-1566:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-1565:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
# TypeError: 'float' object is not subscriptable
# Process Process-1564:
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-1569:
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process Process-1568:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-1572:
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-1571:
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-1574:
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process Process-1576:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-1575:
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Traceback (most recent call last):
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# TypeError: 'float' object is not subscriptable
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-1578:
# Traceback (most recent call last):
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
# Process Process-1580:
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Traceback (most recent call last):
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-1581:
# Traceback (most recent call last):
# TypeError: 'float' object is not subscriptable
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-1579:
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# Process Process-1577:
# TypeError: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-a4a584f38736>", line 270, in doWork
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 270, in <listcomp>
#     return_dict[i] = vstack([align_no_gaps(w, pmiDict, gp1, gp2, th, mode=align_func)
#   File "<ipython-input-4-a4a584f38736>", line 251, in align_no_gaps
#     l = len(aa[0])
# TypeError: 'float' object is not subscriptable
